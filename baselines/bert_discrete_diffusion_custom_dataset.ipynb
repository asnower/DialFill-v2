# %% [markdown]
# # BERT + Discrete (Masked) Diffusion
# A minimal training pipeline (LLaDA / SMDM‑style) implemented with **PyTorch Lightning**.
#
# *Generated automatically on 2025-08-07 11:26:09.*

# %% [markdown]
# ## 1  Environment & installs
# Run the following cell **once** (e.g. on Colab) to install required libraries.

# %%
# !pip install -U torch pytorch-lightning transformers datasets accelerate sentencepiece

# %%
# 顶格放这段，后面再 import transformers
import os
import warnings
import logging
import sys
os.environ["TRANSFORMERS_NO_ADVISORY_WARNINGS"] = "1"   # HF 4.42+ 支持
os.environ["TOKENIZERS_PARALLELISM"] = "false"
warnings.filterwarnings("ignore", message="The current process just got forked")  # 可选
warnings.filterwarnings("ignore", message="A parameter name that contains")
logging.getLogger("transformers").setLevel(logging.ERROR)

home_path = os.getcwd().split("DialFill-DM")[0]
target_path = home_path + "DialFill-DM"
sys.path.append(target_path)

# %% [markdown]
# ## 2  Imports / basic config

# %%
import math, random, torch, torch.nn.functional as F
from dataclasses import dataclass
from typing import Optional
import pytorch_lightning as pl
from datasets import load_dataset
from transformers import AutoTokenizer, BertForMaskedLM

pl.seed_everything(42)

@dataclass
class TrainConfig:
    model_name: str = "bert-base-uncased"
    dataset_name: str = "wikitext"
    dataset_config: str = "wikitext-2-raw-v1"
    text_column: str = "text"
    max_length: int = 128
    batch_size: int = 16
    num_workers: int = 2
    lr: float = 3e-5
    weight_decay: float = 0.01
    max_steps: int = 3000
    warmup_steps: int = 100
    val_check_interval: int = 500
    log_every_n_steps: int = 20
    T: int = 8
    mask_token_mode: str = "mask"
    use_time_embed: bool = False
    random_replace_prob: float = 0.0
    sampling_topk: int = 50
    sampling_temperature: float = 1.0
    gradient_clip_val: float = 1.0
    devices = 'cuda:1'
    precision: str = "bf16-mixed" if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else "16-mixed"

cfg = TrainConfig()
# Out:
# Seed set to 42

# %% [markdown]
# ## 3  Lightning DataModule

# %%
from dataset_process.base_conv import BaseConvDataset, Collator
from transformers import AutoTokenizer

class ConvDataModule(pl.LightningDataModule):
    """
    DataModule that wraps your custom conversational dataset defined in base_conv.py.
    Adjust `dataset` to point at the JSONL (or other) file
    containing your dialogues + knowledge as expected by `BaseConvDataset`.
    """
    def __init__(self, cfg: TrainConfig, dataset: str):
        super().__init__()
        self.cfg = cfg
        self.dataset = dataset
        self.tokenizer = AutoTokenizer.from_pretrained(cfg.model_name, use_fast=True)
        if self.tokenizer.pad_token is None:
            self.tokenizer.add_special_tokens({'pad_token': '[PAD]'})
        self.pad_token_id = self.tokenizer.pad_token_id

    def setup(self, stage=None):
        self.train_ds = BaseConvDataset(
            data=self.dataset,
            tokenizer=self.tokenizer,
            max_history=3,
            max_seq_length=self.cfg.max_length,
            is_generation=False,
            include_triples=True,
        )
        self.val_ds = self.train_ds  # ← replace if you have a separate validation file

    def collate(self, batch):
        collator = Collator(
            pad=self.pad_token_id,
            padding_side='right',
        )
        return collator(batch)

    def train_dataloader(self):
        return torch.utils.data.DataLoader(
            self.train_ds,
            batch_size=self.cfg.batch_size,
            shuffle=True,
            num_workers=self.cfg.num_workers,
            collate_fn=self.collate,
            pin_memory=True,
        )

    def val_dataloader(self):
            return torch.utils.data.DataLoader(
                self.val_ds,
                batch_size=self.cfg.batch_size,
                shuffle=False,
                num_workers=self.cfg.num_workers,
                collate_fn=self.collate,
                pin_memory=True,
            )

# %% [markdown]
# ## 4  Discrete mask scheduler

# %%
class DiscreteMaskScheduler(torch.nn.Module):
    def __init__(self, tokenizer, T: int, max_length: int,
                 random_replace_prob: float = 0.0, schedule: str = "cosine"):
        super().__init__()
        self.T = T
        self.mask_id = tokenizer.mask_token_id
        self.pad_id  = tokenizer.pad_token_id
        self.vocab_size = tokenizer.vocab_size
        self.random_replace_prob = random_replace_prob

        ts = torch.arange(1, T + 1, dtype=torch.float)
        if schedule == "linear":
            m = ts / T
        else:
            m = torch.sin((ts / T) * math.pi / 2.0)

        # **把 m_table 注册成 buffer，随模型一起搬到对应 device**
        self.register_buffer("m_table", torch.clamp(m, 1e-4, 0.9999))

    @torch.no_grad()
    def q_sample(self, x0_ids: torch.LongTensor, t: torch.LongTensor):
        B, L = x0_ids.shape
        # m_t = self.m_table[t-1].view(B, 1).to(x0_ids.device)
        m_t = self.m_table.to(x0_ids.device)[t.cpu() - 1].view(B, 1)
        is_pad = x0_ids.eq(self.pad_id)
        mask_draw = torch.rand(B, L, device=x0_ids.device)
        to_mask = (mask_draw < m_t) & (~is_pad)
        x_t = x0_ids.clone()
        x_t[to_mask] = self.mask_id

        if self.random_replace_prob > 0:
            rnd_draw = torch.rand(B, L, device=x0_ids.device)
            do_replace = (rnd_draw < self.random_replace_prob) & (~to_mask) & (~is_pad)
            rand_ids = torch.randint(0, self.vocab_size, (B, L), device=x0_ids.device)
            rand_ids = torch.where(rand_ids.eq(self.pad_id)|rand_ids.eq(self.mask_id),
                                   (rand_ids+1) % self.vocab_size, rand_ids)
            x_t[do_replace] = rand_ids[do_replace]
        return x_t, to_mask

# %% [markdown]
# ## 5  LightningModule (BERT denoiser)

# %%
class DiffusionBert(pl.LightningModule):
    def __init__(self, cfg: TrainConfig, tokenizer):
        super().__init__()
        self.save_hyperparameters()
        self.cfg = cfg
        self.tokenizer = tokenizer
        self.bert = BertForMaskedLM.from_pretrained(cfg.model_name)
        self.bert.resize_token_embeddings(len(tokenizer))
        self.scheduler = DiscreteMaskScheduler(tokenizer, cfg.T, cfg.max_length,
                                               cfg.random_replace_prob)
        if cfg.use_time_embed:
            self.time_embed = torch.nn.Embedding(cfg.T+1, self.bert.config.hidden_size)
        else:
            self.time_embed = None

    def configure_optimizers(self):
        no_decay = ['bias', 'LayerNorm.weight']
        pg = [
            {'params': [p for n,p in self.named_parameters() if not any(nd in n for nd in no_decay)],
             'weight_decay': self.cfg.weight_decay},
            {'params': [p for n,p in self.named_parameters() if any(nd in n for nd in no_decay)],
             'weight_decay': 0.0},
        ]
        opt = torch.optim.AdamW(pg, lr=self.cfg.lr)
        sched = torch.optim.lr_scheduler.LinearLR(opt, start_factor=0.1, total_iters=self.cfg.warmup_steps)
        return {'optimizer': opt, 'lr_scheduler': {'scheduler': sched, 'interval':'step'}}

    def _add_time(self, emb, t):
        if self.time_embed is None:
            return emb
        return emb + self.time_embed(t.clamp(0,self.cfg.T)).unsqueeze(1)

    def training_step(self, batch, _):
        x0, attn = batch['input_ids'], batch['attention_mask']
        t = torch.randint(1, self.cfg.T+1, (x0.size(0),), device=self.device)
        xt, to_mask = self.scheduler.q_sample(x0, t)
        if self.time_embed is not None:
            emb = self.bert.get_input_embeddings()(xt)
            logits = self.bert(inputs_embeds=self._add_time(emb,t),
                               attention_mask=attn,return_dict=True).logits
        else:
            logits = self.bert(input_ids=xt, attention_mask=attn, return_dict=True).logits
        loss = F.cross_entropy(logits[to_mask], x0[to_mask]) if to_mask.any() else logits.new_zeros(())
        self.log('train/loss', loss, prog_bar=True, on_step=True)
        return loss

    def validation_step(self, batch, _):
        x0, attn = batch['input_ids'], batch['attention_mask']
        t = torch.full((x0.size(0),), math.ceil(self.cfg.T/2), device=self.device)
        xt, to_mask = self.scheduler.q_sample(x0, t)
        if self.time_embed is not None:
            emb = self.bert.get_input_embeddings()(xt)
            logits = self.bert(inputs_embeds=self._add_time(emb,t),
                               attention_mask=attn,return_dict=True).logits
        else:
            logits = self.bert(input_ids=xt, attention_mask=attn, return_dict=True).logits
        loss = F.cross_entropy(logits[to_mask], x0[to_mask]) if to_mask.any() else logits.new_zeros(())
        self.log('val/loss', loss, prog_bar=True, on_epoch=True)

    @torch.no_grad()
    def sample(self, prompts, num_steps=None, start_mask_ratio=1.0):
        self.eval()
        num_steps = num_steps or self.cfg.T
        enc = self.tokenizer(prompts, return_tensors='pt', padding='max_length',
                             truncation=True, max_length=self.cfg.max_length).to(self.device)
        x = enc.input_ids.clone()
        attn = enc.attention_mask
        mask_id = self.tokenizer.mask_token_id
        # initial masking
        rnd = torch.rand_like(x, dtype=torch.float)
        mask_init = (rnd < start_mask_ratio) & attn.bool()
        x[mask_init] = mask_id
        B = x.size(0)
        for step in range(num_steps,0,-1):
            t = torch.full((B,), step, device=self.device, dtype=torch.long)
            if self.time_embed is not None:
                emb = self.bert.get_input_embeddings()(x)
                logits = self.bert(inputs_embeds=self._add_time(emb,t),
                                   attention_mask=attn,return_dict=True).logits
            else:
                logits = self.bert(input_ids=x, attention_mask=attn, return_dict=True).logits
            probs = torch.softmax(logits/self.cfg.sampling_temperature, dim=-1)
            topk = min(self.cfg.sampling_topk, probs.size(-1))
            if topk < probs.size(-1):
                topk_probs, topk_ids = torch.topk(probs, k=topk, dim=-1)
                topk_probs = topk_probs / topk_probs.sum(dim=-1, keepdim=True)
                idx = torch.distributions.Categorical(topk_probs).sample()
                sampled = topk_ids.gather(-1, idx.unsqueeze(-1)).squeeze(-1)
            else:
                sampled = torch.distributions.Categorical(probs).sample()
            fill = x.eq(mask_id) & attn.bool()
            x[fill] = sampled[fill]
        return self.tokenizer.batch_decode(x, skip_special_tokens=True)

# %% [markdown]
# ## 6  Train

# %%
from huggingface_hub import login
from datasets import load_dataset
login(token="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")
# --- Use your dataset ------------------------------------------------------------
dataset = load_dataset("asnower/opendialkg")
dm = ConvDataModule(cfg, dataset['train'])
# Out:
# Using the latest cached version of the dataset since asnower/opendialkg couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/xueqiang/.cache/huggingface/datasets/asnower___opendialkg/default/0.0.0/309a8fc4ba0488c87e42e5a5ef2648b6c3144f0f (last modified on Thu Aug  7 21:22:25 2025).
# /home/xueqiang/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# --- model & trainer ----------------------------------------------------------------
model = DiffusionBert(cfg, dm.tokenizer)  # Assuming DiffusionBert class defined earlier
trainer = pl.Trainer(
    max_steps=cfg.max_steps,
    gradient_clip_val=cfg.gradient_clip_val,
    devices='auto',
    accelerator='auto',
    precision=cfg.precision,
    log_every_n_steps=cfg.log_every_n_steps,
    val_check_interval=cfg.val_check_interval,
)

trainer.fit(model, dm)
# Out:
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# 2025-08-08 17:58:07.328205: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-08 17:58:07.343601: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-08 17:58:07.348265: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-08 17:58:07.359928: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-08 17:58:08.095351: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# data 2 is deleted! because of the response_len=23 or len(history)=0
# data 7 is deleted! because of the response_len=29 or len(history)=0
# data 10 is deleted! because of the response_len=22 or len(history)=0
# data 15 is deleted! because of the response_len=30 or len(history)=0
# data 20 is deleted! because of the response_len=34 or len(history)=0
# data 24 is deleted! because of the response_len=8 or len(history)=0
# data 50 is deleted! because of the response_len=24 or len(history)=0
# data 55 is deleted! because of the response_len=21 or len(history)=0
# data 70 is deleted! because of the response_len=25 or len(history)=0
# data 76 is deleted! because of the response_len=26 or len(history)=0
# data 99 is deleted! because of the response_len=13 or len(history)=0
# data 122 is deleted! because of the response_len=39 or len(history)=0
# data 125 is deleted! because of the response_len=16 or len(history)=0
# data 151 is deleted! because of the response_len=19 or len(history)=0
# data 158 is deleted! because of the response_len=129 or len(history)=0
# data 187 is deleted! because of the response_len=19 or len(history)=0
# data 192 is deleted! because of the response_len=16 or len(history)=0
# data 193 is deleted! because of the response_len=22 or len(history)=0
# data 197 is deleted! because of the response_len=26 or len(history)=0
# data 216 is deleted! because of the response_len=26 or len(history)=0
# data 228 is deleted! because of the response_len=8 or len(history)=0
# data 234 is deleted! because of the response_len=35 or len(history)=0
# data 242 is deleted! because of the response_len=31 or len(history)=0
# data 291 is deleted! because of the response_len=8 or len(history)=0
# data 299 is deleted! because of the response_len=23 or len(history)=0
# data 300 is deleted! because of the response_len=18 or len(history)=0
# data 318 is deleted! because of the response_len=21 or len(history)=0
# data 331 is deleted! because of the response_len=22 or len(history)=0
# data 338 is deleted! because of the response_len=15 or len(history)=0
# data 340 is deleted! because of the response_len=43 or len(history)=0
# data 342 is deleted! because of the response_len=25 or len(history)=0
# data 363 is deleted! because of the response_len=32 or len(history)=0
# data 377 is deleted! because of the response_len=33 or len(history)=0
# data 381 is deleted! because of the response_len=19 or len(history)=0
# data 382 is deleted! because of the response_len=23 or len(history)=0
# data 385 is deleted! because of the response_len=23 or len(history)=0
# data 488 is deleted! because of the response_len=25 or len(history)=0
# data 500 is deleted! because of the response_len=32 or len(history)=0
# data 538 is deleted! because of the response_len=22 or len(history)=0
# data 550 is deleted! because of the response_len=21 or len(history)=0
# data 562 is deleted! because of the response_len=22 or len(history)=0
# data 569 is deleted! because of the response_len=30 or len(history)=0
# data 596 is deleted! because of the response_len=26 or len(history)=0
# data 612 is deleted! because of the response_len=31 or len(history)=0
# data 618 is deleted! because of the response_len=20 or len(history)=0
# data 638 is deleted! because of the response_len=20 or len(history)=0
# data 640 is deleted! because of the response_len=23 or len(history)=0
# data 643 is deleted! because of the response_len=20 or len(history)=0
# data 644 is deleted! because of the response_len=17 or len(history)=0
# data 646 is deleted! because of the response_len=25 or len(history)=0
# data 659 is deleted! because of the response_len=33 or len(history)=0
# data 667 is deleted! because of the response_len=30 or len(history)=0
# data 674 is deleted! because of the response_len=33 or len(history)=0
# data 677 is deleted! because of the response_len=27 or len(history)=0
# data 686 is deleted! because of the response_len=23 or len(history)=0
# data 689 is deleted! because of the response_len=29 or len(history)=0
# data 725 is deleted! because of the response_len=17 or len(history)=0
# data 726 is deleted! because of the response_len=34 or len(history)=0
# data 727 is deleted! because of the response_len=10 or len(history)=0
# data 741 is deleted! because of the response_len=14 or len(history)=0
# data 787 is deleted! because of the response_len=18 or len(history)=0
# data 791 is deleted! because of the response_len=11 or len(history)=0
# data 795 is deleted! because of the response_len=10 or len(history)=0
# data 823 is deleted! because of the response_len=29 or len(history)=0
# data 841 is deleted! because of the response_len=17 or len(history)=0
# data 848 is deleted! because of the response_len=35 or len(history)=0
# data 858 is deleted! because of the response_len=25 or len(history)=0
# data 871 is deleted! because of the response_len=16 or len(history)=0
# data 874 is deleted! because of the response_len=35 or len(history)=0
# data 881 is deleted! because of the response_len=7 or len(history)=0
# data 893 is deleted! because of the response_len=27 or len(history)=0
# data 903 is deleted! because of the response_len=18 or len(history)=0
# data 914 is deleted! because of the response_len=19 or len(history)=0
# data 947 is deleted! because of the response_len=26 or len(history)=0
# data 952 is deleted! because of the response_len=14 or len(history)=0
# data 956 is deleted! because of the response_len=23 or len(history)=0
# data 977 is deleted! because of the response_len=33 or len(history)=0
# data 985 is deleted! because of the response_len=52 or len(history)=0
# data 986 is deleted! because of the response_len=28 or len(history)=0
# data 1024 is deleted! because of the response_len=15 or len(history)=0
# data 1043 is deleted! because of the response_len=16 or len(history)=0
# data 1071 is deleted! because of the response_len=31 or len(history)=0
# data 1088 is deleted! because of the response_len=22 or len(history)=0
# data 1089 is deleted! because of the response_len=15 or len(history)=0
# data 1111 is deleted! because of the response_len=17 or len(history)=0
# data 1126 is deleted! because of the response_len=32 or len(history)=0
# data 1175 is deleted! because of the response_len=33 or len(history)=0
# data 1193 is deleted! because of the response_len=18 or len(history)=0
# data 1208 is deleted! because of the response_len=38 or len(history)=0
# data 1221 is deleted! because of the response_len=26 or len(history)=0
# data 1229 is deleted! because of the response_len=14 or len(history)=0
# data 1250 is deleted! because of the response_len=56 or len(history)=0
# data 1254 is deleted! because of the response_len=36 or len(history)=0
# data 1277 is deleted! because of the response_len=15 or len(history)=0
# data 1283 is deleted! because of the response_len=15 or len(history)=0
# data 1307 is deleted! because of the response_len=30 or len(history)=0
# data 1308 is deleted! because of the response_len=34 or len(history)=0
# data 1343 is deleted! because of the response_len=33 or len(history)=0
# data 1371 is deleted! because of the response_len=26 or len(history)=0
# data 1412 is deleted! because of the response_len=26 or len(history)=0
# data 1428 is deleted! because of the response_len=39 or len(history)=0
# data 1431 is deleted! because of the response_len=26 or len(history)=0
# data 1441 is deleted! because of the response_len=38 or len(history)=0
# data 1468 is deleted! because of the response_len=20 or len(history)=0
# data 1477 is deleted! because of the response_len=10 or len(history)=0
# data 1497 is deleted! because of the response_len=32 or len(history)=0
# data 1526 is deleted! because of the response_len=42 or len(history)=0
# data 1532 is deleted! because of the response_len=5 or len(history)=0
# data 1544 is deleted! because of the response_len=23 or len(history)=0
# data 1545 is deleted! because of the response_len=17 or len(history)=0
# data 1554 is deleted! because of the response_len=27 or len(history)=0
# data 1575 is deleted! because of the response_len=18 or len(history)=0
# data 1586 is deleted! because of the response_len=21 or len(history)=0
# data 1593 is deleted! because of the response_len=12 or len(history)=0
# data 1604 is deleted! because of the response_len=34 or len(history)=0
# data 1613 is deleted! because of the response_len=16 or len(history)=0
# data 1627 is deleted! because of the response_len=28 or len(history)=0
# data 1644 is deleted! because of the response_len=19 or len(history)=0
# data 1658 is deleted! because of the response_len=36 or len(history)=0
# data 1717 is deleted! because of the response_len=20 or len(history)=0
# data 1733 is deleted! because of the response_len=27 or len(history)=0
# data 1740 is deleted! because of the response_len=26 or len(history)=0
# data 1751 is deleted! because of the response_len=15 or len(history)=0
# data 1766 is deleted! because of the response_len=21 or len(history)=0
# data 1767 is deleted! because of the response_len=25 or len(history)=0
# data 1798 is deleted! because of the response_len=23 or len(history)=0
# data 1813 is deleted! because of the response_len=29 or len(history)=0
# data 1819 is deleted! because of the response_len=23 or len(history)=0
# data 1831 is deleted! because of the response_len=42 or len(history)=0
# data 1832 is deleted! because of the response_len=18 or len(history)=0
# data 1833 is deleted! because of the response_len=16 or len(history)=0
# data 1842 is deleted! because of the response_len=16 or len(history)=0
# data 1857 is deleted! because of the response_len=18 or len(history)=0
# data 1861 is deleted! because of the response_len=12 or len(history)=0
# data 1888 is deleted! because of the response_len=19 or len(history)=0
# data 1962 is deleted! because of the response_len=18 or len(history)=0
# data 1963 is deleted! because of the response_len=20 or len(history)=0
# data 1970 is deleted! because of the response_len=27 or len(history)=0
# data 1993 is deleted! because of the response_len=31 or len(history)=0
# data 2002 is deleted! because of the response_len=24 or len(history)=0
# data 2010 is deleted! because of the response_len=6 or len(history)=0
# data 2013 is deleted! because of the response_len=35 or len(history)=0
# data 2030 is deleted! because of the response_len=25 or len(history)=0
# data 2042 is deleted! because of the response_len=20 or len(history)=0
# data 2056 is deleted! because of the response_len=23 or len(history)=0
# data 2077 is deleted! because of the response_len=28 or len(history)=0
# data 2091 is deleted! because of the response_len=25 or len(history)=0
# data 2105 is deleted! because of the response_len=18 or len(history)=0
# data 2117 is deleted! because of the response_len=17 or len(history)=0
# data 2123 is deleted! because of the response_len=19 or len(history)=0
# data 2137 is deleted! because of the response_len=23 or len(history)=0
# data 2141 is deleted! because of the response_len=28 or len(history)=0
# data 2159 is deleted! because of the response_len=25 or len(history)=0
# data 2160 is deleted! because of the response_len=12 or len(history)=0
# data 2170 is deleted! because of the response_len=6 or len(history)=0
# data 2181 is deleted! because of the response_len=27 or len(history)=0
# data 2203 is deleted! because of the response_len=24 or len(history)=0
# data 2209 is deleted! because of the response_len=26 or len(history)=0
# data 2223 is deleted! because of the response_len=21 or len(history)=0
# data 2226 is deleted! because of the response_len=26 or len(history)=0
# data 2229 is deleted! because of the response_len=28 or len(history)=0
# data 2240 is deleted! because of the response_len=33 or len(history)=0
# data 2263 is deleted! because of the response_len=16 or len(history)=0
# data 2282 is deleted! because of the response_len=26 or len(history)=0
# data 2297 is deleted! because of the response_len=26 or len(history)=0
# data 2317 is deleted! because of the response_len=10 or len(history)=0
# data 2325 is deleted! because of the response_len=28 or len(history)=0
# data 2336 is deleted! because of the response_len=17 or len(history)=0
# data 2346 is deleted! because of the response_len=11 or len(history)=0
# data 2375 is deleted! because of the response_len=27 or len(history)=0
# data 2376 is deleted! because of the response_len=28 or len(history)=0
# data 2377 is deleted! because of the response_len=22 or len(history)=0
# data 2384 is deleted! because of the response_len=32 or len(history)=0
# data 2385 is deleted! because of the response_len=42 or len(history)=0
# data 2387 is deleted! because of the response_len=39 or len(history)=0
# data 2436 is deleted! because of the response_len=22 or len(history)=0
# data 2472 is deleted! because of the response_len=16 or len(history)=0
# data 2474 is deleted! because of the response_len=22 or len(history)=0
# data 2481 is deleted! because of the response_len=35 or len(history)=0
# data 2485 is deleted! because of the response_len=33 or len(history)=0
# data 2497 is deleted! because of the response_len=25 or len(history)=0
# data 2566 is deleted! because of the response_len=44 or len(history)=0
# data 2572 is deleted! because of the response_len=28 or len(history)=0
# data 2579 is deleted! because of the response_len=17 or len(history)=0
# data 2582 is deleted! because of the response_len=24 or len(history)=0
# data 2584 is deleted! because of the response_len=108 or len(history)=0
# data 2586 is deleted! because of the response_len=30 or len(history)=0
# data 2608 is deleted! because of the response_len=16 or len(history)=0
# data 2661 is deleted! because of the response_len=19 or len(history)=0
# data 2669 is deleted! because of the response_len=32 or len(history)=0
# data 2679 is deleted! because of the response_len=27 or len(history)=0
# data 2687 is deleted! because of the response_len=30 or len(history)=0
# data 2688 is deleted! because of the response_len=34 or len(history)=0
# data 2689 is deleted! because of the response_len=23 or len(history)=0
# data 2702 is deleted! because of the response_len=30 or len(history)=0
# data 2716 is deleted! because of the response_len=15 or len(history)=0
# data 2722 is deleted! because of the response_len=21 or len(history)=0
# data 2745 is deleted! because of the response_len=22 or len(history)=0
# data 2777 is deleted! because of the response_len=27 or len(history)=0
# data 2783 is deleted! because of the response_len=17 or len(history)=0
# data 2790 is deleted! because of the response_len=70 or len(history)=0
# data 2806 is deleted! because of the response_len=24 or len(history)=0
# data 2826 is deleted! because of the response_len=25 or len(history)=0
# data 2828 is deleted! because of the response_len=32 or len(history)=0
# data 2843 is deleted! because of the response_len=28 or len(history)=0
# data 2851 is deleted! because of the response_len=23 or len(history)=0
# data 2857 is deleted! because of the response_len=24 or len(history)=0
# data 2860 is deleted! because of the response_len=39 or len(history)=0
# data 2865 is deleted! because of the response_len=24 or len(history)=0
# data 2892 is deleted! because of the response_len=9 or len(history)=0
# data 2914 is deleted! because of the response_len=14 or len(history)=0
# data 2922 is deleted! because of the response_len=17 or len(history)=0
# data 2926 is deleted! because of the response_len=18 or len(history)=0
# data 2977 is deleted! because of the response_len=33 or len(history)=0
# data 2979 is deleted! because of the response_len=19 or len(history)=0
# data 2993 is deleted! because of the response_len=56 or len(history)=0
# data 3013 is deleted! because of the response_len=25 or len(history)=0
# data 3045 is deleted! because of the response_len=24 or len(history)=0
# data 3056 is deleted! because of the response_len=25 or len(history)=0
# data 3080 is deleted! because of the response_len=25 or len(history)=0
# data 3089 is deleted! because of the response_len=44 or len(history)=0
# data 3185 is deleted! because of the response_len=19 or len(history)=0
# data 3186 is deleted! because of the response_len=23 or len(history)=0
# data 3194 is deleted! because of the response_len=23 or len(history)=0
# data 3216 is deleted! because of the response_len=41 or len(history)=0
# data 3238 is deleted! because of the response_len=30 or len(history)=0
# data 3240 is deleted! because of the response_len=21 or len(history)=0
# data 3241 is deleted! because of the response_len=13 or len(history)=0
# data 3242 is deleted! because of the response_len=30 or len(history)=0
# data 3248 is deleted! because of the response_len=18 or len(history)=0
# data 3263 is deleted! because of the response_len=28 or len(history)=0
# data 3264 is deleted! because of the response_len=25 or len(history)=0
# data 3280 is deleted! because of the response_len=29 or len(history)=0
# data 3294 is deleted! because of the response_len=30 or len(history)=0
# data 3322 is deleted! because of the response_len=27 or len(history)=0
# data 3327 is deleted! because of the response_len=23 or len(history)=0
# data 3339 is deleted! because of the response_len=32 or len(history)=0
# data 3344 is deleted! because of the response_len=25 or len(history)=0
# data 3357 is deleted! because of the response_len=34 or len(history)=0
# data 3359 is deleted! because of the response_len=17 or len(history)=0
# data 3375 is deleted! because of the response_len=11 or len(history)=0
# data 3382 is deleted! because of the response_len=14 or len(history)=0
# data 3397 is deleted! because of the response_len=25 or len(history)=0
# data 3411 is deleted! because of the response_len=30 or len(history)=0
# data 3440 is deleted! because of the response_len=36 or len(history)=0
# data 3452 is deleted! because of the response_len=30 or len(history)=0
# data 3457 is deleted! because of the response_len=33 or len(history)=0
# data 3460 is deleted! because of the response_len=32 or len(history)=0
# data 3471 is deleted! because of the response_len=34 or len(history)=0
# data 3479 is deleted! because of the response_len=11 or len(history)=0
# data 3492 is deleted! because of the response_len=31 or len(history)=0
# data 3512 is deleted! because of the response_len=19 or len(history)=0
# data 3516 is deleted! because of the response_len=12 or len(history)=0
# data 3520 is deleted! because of the response_len=22 or len(history)=0
# data 3535 is deleted! because of the response_len=12 or len(history)=0
# data 3543 is deleted! because of the response_len=27 or len(history)=0
# data 3563 is deleted! because of the response_len=23 or len(history)=0
# data 3650 is deleted! because of the response_len=29 or len(history)=0
# data 3653 is deleted! because of the response_len=35 or len(history)=0
# data 3656 is deleted! because of the response_len=27 or len(history)=0
# data 3662 is deleted! because of the response_len=31 or len(history)=0
# data 3685 is deleted! because of the response_len=21 or len(history)=0
# data 3693 is deleted! because of the response_len=36 or len(history)=0
# data 3699 is deleted! because of the response_len=7 or len(history)=0
# data 3718 is deleted! because of the response_len=20 or len(history)=0
# data 3720 is deleted! because of the response_len=39 or len(history)=0
# data 3723 is deleted! because of the response_len=18 or len(history)=0
# data 3726 is deleted! because of the response_len=7 or len(history)=0
# data 3728 is deleted! because of the response_len=34 or len(history)=0
# data 3732 is deleted! because of the response_len=20 or len(history)=0
# data 3752 is deleted! because of the response_len=37 or len(history)=0
# data 3753 is deleted! because of the response_len=24 or len(history)=0
# data 3759 is deleted! because of the response_len=31 or len(history)=0
# data 3765 is deleted! because of the response_len=22 or len(history)=0
# data 3772 is deleted! because of the response_len=22 or len(history)=0
# data 3780 is deleted! because of the response_len=42 or len(history)=0
# data 3796 is deleted! because of the response_len=17 or len(history)=0
# data 3808 is deleted! because of the response_len=26 or len(history)=0
# data 3843 is deleted! because of the response_len=20 or len(history)=0
# data 3845 is deleted! because of the response_len=40 or len(history)=0
# data 3859 is deleted! because of the response_len=25 or len(history)=0
# data 3864 is deleted! because of the response_len=20 or len(history)=0
# data 3878 is deleted! because of the response_len=26 or len(history)=0
# data 3892 is deleted! because of the response_len=18 or len(history)=0
# data 3900 is deleted! because of the response_len=27 or len(history)=0
# data 3906 is deleted! because of the response_len=20 or len(history)=0
# data 3947 is deleted! because of the response_len=13 or len(history)=0
# data 3964 is deleted! because of the response_len=23 or len(history)=0
# data 3967 is deleted! because of the response_len=27 or len(history)=0
# data 3975 is deleted! because of the response_len=35 or len(history)=0
# data 4001 is deleted! because of the response_len=47 or len(history)=0
# data 4007 is deleted! because of the response_len=31 or len(history)=0
# data 4019 is deleted! because of the response_len=20 or len(history)=0
# data 4024 is deleted! because of the response_len=18 or len(history)=0
# data 4038 is deleted! because of the response_len=27 or len(history)=0
# data 4065 is deleted! because of the response_len=20 or len(history)=0
# data 4069 is deleted! because of the response_len=30 or len(history)=0
# data 4111 is deleted! because of the response_len=28 or len(history)=0
# data 4119 is deleted! because of the response_len=11 or len(history)=0
# data 4128 is deleted! because of the response_len=32 or len(history)=0
# data 4139 is deleted! because of the response_len=31 or len(history)=0
# data 4148 is deleted! because of the response_len=21 or len(history)=0
# data 4149 is deleted! because of the response_len=12 or len(history)=0
# data 4171 is deleted! because of the response_len=13 or len(history)=0
# data 4173 is deleted! because of the response_len=47 or len(history)=0
# data 4188 is deleted! because of the response_len=10 or len(history)=0
# data 4195 is deleted! because of the response_len=21 or len(history)=0
# data 4196 is deleted! because of the response_len=29 or len(history)=0
# data 4245 is deleted! because of the response_len=23 or len(history)=0
# data 4248 is deleted! because of the response_len=11 or len(history)=0
# data 4270 is deleted! because of the response_len=37 or len(history)=0
# data 4294 is deleted! because of the response_len=11 or len(history)=0
# data 4307 is deleted! because of the response_len=35 or len(history)=0
# data 4310 is deleted! because of the response_len=27 or len(history)=0
# data 4326 is deleted! because of the response_len=45 or len(history)=0
# data 4328 is deleted! because of the response_len=26 or len(history)=0
# data 4330 is deleted! because of the response_len=17 or len(history)=0
# data 4346 is deleted! because of the response_len=24 or len(history)=0
# data 4382 is deleted! because of the response_len=22 or len(history)=0
# data 4385 is deleted! because of the response_len=24 or len(history)=0
# data 4393 is deleted! because of the response_len=34 or len(history)=0
# data 4417 is deleted! because of the response_len=23 or len(history)=0
# data 4434 is deleted! because of the response_len=11 or len(history)=0
# data 4457 is deleted! because of the response_len=29 or len(history)=0
# data 4460 is deleted! because of the response_len=43 or len(history)=0
# data 4467 is deleted! because of the response_len=30 or len(history)=0
# data 4497 is deleted! because of the response_len=21 or len(history)=0
# data 4499 is deleted! because of the response_len=12 or len(history)=0
# data 4504 is deleted! because of the response_len=19 or len(history)=0
# data 4507 is deleted! because of the response_len=32 or len(history)=0
# data 4508 is deleted! because of the response_len=33 or len(history)=0
# data 4518 is deleted! because of the response_len=21 or len(history)=0
# data 4548 is deleted! because of the response_len=20 or len(history)=0
# data 4552 is deleted! because of the response_len=22 or len(history)=0
# data 4555 is deleted! because of the response_len=35 or len(history)=0
# data 4560 is deleted! because of the response_len=22 or len(history)=0
# data 4567 is deleted! because of the response_len=21 or len(history)=0
# data 4573 is deleted! because of the response_len=27 or len(history)=0
# data 4596 is deleted! because of the response_len=24 or len(history)=0
# data 4623 is deleted! because of the response_len=54 or len(history)=0
# data 4655 is deleted! because of the response_len=23 or len(history)=0
# data 4656 is deleted! because of the response_len=20 or len(history)=0
# data 4708 is deleted! because of the response_len=21 or len(history)=0
# data 4722 is deleted! because of the response_len=23 or len(history)=0
# data 4731 is deleted! because of the response_len=33 or len(history)=0
# data 4736 is deleted! because of the response_len=11 or len(history)=0
# data 4744 is deleted! because of the response_len=33 or len(history)=0
# data 4747 is deleted! because of the response_len=13 or len(history)=0
# data 4771 is deleted! because of the response_len=18 or len(history)=0
# data 4775 is deleted! because of the response_len=14 or len(history)=0
# data 4794 is deleted! because of the response_len=29 or len(history)=0
# data 4800 is deleted! because of the response_len=15 or len(history)=0
# data 4803 is deleted! because of the response_len=19 or len(history)=0
# data 4838 is deleted! because of the response_len=28 or len(history)=0
# data 4852 is deleted! because of the response_len=22 or len(history)=0
# data 4859 is deleted! because of the response_len=14 or len(history)=0
# data 4881 is deleted! because of the response_len=36 or len(history)=0
# data 4915 is deleted! because of the response_len=13 or len(history)=0
# data 4916 is deleted! because of the response_len=49 or len(history)=0
# data 4921 is deleted! because of the response_len=7 or len(history)=0
# data 4925 is deleted! because of the response_len=20 or len(history)=0
# data 4930 is deleted! because of the response_len=46 or len(history)=0
# data 4938 is deleted! because of the response_len=21 or len(history)=0
# data 4969 is deleted! because of the response_len=20 or len(history)=0
# data 4973 is deleted! because of the response_len=29 or len(history)=0
# data 4979 is deleted! because of the response_len=66 or len(history)=0
# data 4980 is deleted! because of the response_len=28 or len(history)=0
# data 5001 is deleted! because of the response_len=18 or len(history)=0
# data 5002 is deleted! because of the response_len=16 or len(history)=0
# data 5013 is deleted! because of the response_len=25 or len(history)=0
# data 5017 is deleted! because of the response_len=26 or len(history)=0
# data 5021 is deleted! because of the response_len=24 or len(history)=0
# data 5022 is deleted! because of the response_len=29 or len(history)=0
# data 5027 is deleted! because of the response_len=27 or len(history)=0
# data 5035 is deleted! because of the response_len=22 or len(history)=0
# data 5043 is deleted! because of the response_len=12 or len(history)=0
# data 5058 is deleted! because of the response_len=35 or len(history)=0
# data 5063 is deleted! because of the response_len=19 or len(history)=0
# data 5069 is deleted! because of the response_len=17 or len(history)=0
# data 5070 is deleted! because of the response_len=36 or len(history)=0
# data 5075 is deleted! because of the response_len=20 or len(history)=0
# data 5099 is deleted! because of the response_len=8 or len(history)=0
# data 5107 is deleted! because of the response_len=31 or len(history)=0
# data 5111 is deleted! because of the response_len=16 or len(history)=0
# data 5112 is deleted! because of the response_len=68 or len(history)=0
# data 5113 is deleted! because of the response_len=36 or len(history)=0
# data 5120 is deleted! because of the response_len=14 or len(history)=0
# data 5122 is deleted! because of the response_len=37 or len(history)=0
# data 5138 is deleted! because of the response_len=31 or len(history)=0
# data 5145 is deleted! because of the response_len=20 or len(history)=0
# data 5159 is deleted! because of the response_len=21 or len(history)=0
# data 5160 is deleted! because of the response_len=23 or len(history)=0
# data 5169 is deleted! because of the response_len=26 or len(history)=0
# data 5184 is deleted! because of the response_len=21 or len(history)=0
# data 5201 is deleted! because of the response_len=29 or len(history)=0
# data 5211 is deleted! because of the response_len=20 or len(history)=0
# data 5213 is deleted! because of the response_len=20 or len(history)=0
# data 5230 is deleted! because of the response_len=35 or len(history)=0
# data 5233 is deleted! because of the response_len=20 or len(history)=0
# data 5234 is deleted! because of the response_len=34 or len(history)=0
# data 5254 is deleted! because of the response_len=26 or len(history)=0
# data 5255 is deleted! because of the response_len=22 or len(history)=0
# data 5284 is deleted! because of the response_len=30 or len(history)=0
# data 5285 is deleted! because of the response_len=33 or len(history)=0
# data 5296 is deleted! because of the response_len=38 or len(history)=0
# data 5298 is deleted! because of the response_len=26 or len(history)=0
# data 5325 is deleted! because of the response_len=19 or len(history)=0
# data 5336 is deleted! because of the response_len=28 or len(history)=0
# data 5346 is deleted! because of the response_len=45 or len(history)=0
# data 5381 is deleted! because of the response_len=18 or len(history)=0
# data 5400 is deleted! because of the response_len=38 or len(history)=0
# data 5401 is deleted! because of the response_len=25 or len(history)=0
# data 5418 is deleted! because of the response_len=17 or len(history)=0
# data 5421 is deleted! because of the response_len=26 or len(history)=0
# data 5441 is deleted! because of the response_len=33 or len(history)=0
# data 5467 is deleted! because of the response_len=28 or len(history)=0
# data 5481 is deleted! because of the response_len=23 or len(history)=0
# data 5493 is deleted! because of the response_len=22 or len(history)=0
# data 5503 is deleted! because of the response_len=34 or len(history)=0
# data 5543 is deleted! because of the response_len=14 or len(history)=0
# data 5545 is deleted! because of the response_len=16 or len(history)=0
# data 5548 is deleted! because of the response_len=15 or len(history)=0
# data 5556 is deleted! because of the response_len=20 or len(history)=0
# data 5564 is deleted! because of the response_len=14 or len(history)=0
# data 5578 is deleted! because of the response_len=12 or len(history)=0
# data 5579 is deleted! because of the response_len=23 or len(history)=0
# data 5585 is deleted! because of the response_len=24 or len(history)=0
# data 5587 is deleted! because of the response_len=25 or len(history)=0
# data 5594 is deleted! because of the response_len=18 or len(history)=0
# data 5599 is deleted! because of the response_len=29 or len(history)=0
# data 5603 is deleted! because of the response_len=11 or len(history)=0
# data 5639 is deleted! because of the response_len=11 or len(history)=0
# data 5656 is deleted! because of the response_len=33 or len(history)=0
# data 5675 is deleted! because of the response_len=37 or len(history)=0
# data 5684 is deleted! because of the response_len=29 or len(history)=0
# data 5711 is deleted! because of the response_len=20 or len(history)=0
# data 5717 is deleted! because of the response_len=22 or len(history)=0
# data 5753 is deleted! because of the response_len=37 or len(history)=0
# data 5774 is deleted! because of the response_len=20 or len(history)=0
# data 5800 is deleted! because of the response_len=48 or len(history)=0
# data 5808 is deleted! because of the response_len=19 or len(history)=0
# data 5831 is deleted! because of the response_len=24 or len(history)=0
# data 5832 is deleted! because of the response_len=24 or len(history)=0
# data 5871 is deleted! because of the response_len=19 or len(history)=0
# data 5884 is deleted! because of the response_len=25 or len(history)=0
# data 5902 is deleted! because of the response_len=8 or len(history)=0
# data 5903 is deleted! because of the response_len=39 or len(history)=0
# data 5947 is deleted! because of the response_len=35 or len(history)=0
# data 5980 is deleted! because of the response_len=45 or len(history)=0
# data 6022 is deleted! because of the response_len=21 or len(history)=0
# data 6045 is deleted! because of the response_len=8 or len(history)=0
# data 6053 is deleted! because of the response_len=14 or len(history)=0
# data 6068 is deleted! because of the response_len=33 or len(history)=0
# data 6069 is deleted! because of the response_len=33 or len(history)=0
# data 6078 is deleted! because of the response_len=45 or len(history)=0
# data 6081 is deleted! because of the response_len=23 or len(history)=0
# data 6107 is deleted! because of the response_len=24 or len(history)=0
# data 6134 is deleted! because of the response_len=23 or len(history)=0
# data 6136 is deleted! because of the response_len=28 or len(history)=0
# data 6152 is deleted! because of the response_len=21 or len(history)=0
# data 6164 is deleted! because of the response_len=18 or len(history)=0
# data 6179 is deleted! because of the response_len=12 or len(history)=0
# data 6183 is deleted! because of the response_len=15 or len(history)=0
# data 6201 is deleted! because of the response_len=26 or len(history)=0
# data 6207 is deleted! because of the response_len=16 or len(history)=0
# data 6225 is deleted! because of the response_len=38 or len(history)=0
# data 6250 is deleted! because of the response_len=22 or len(history)=0
# data 6262 is deleted! because of the response_len=25 or len(history)=0
# data 6296 is deleted! because of the response_len=14 or len(history)=0
# data 6298 is deleted! because of the response_len=18 or len(history)=0
# data 6304 is deleted! because of the response_len=17 or len(history)=0
# data 6329 is deleted! because of the response_len=19 or len(history)=0
# data 6341 is deleted! because of the response_len=19 or len(history)=0
# data 6354 is deleted! because of the response_len=35 or len(history)=0
# data 6363 is deleted! because of the response_len=27 or len(history)=0
# data 6370 is deleted! because of the response_len=14 or len(history)=0
# data 6391 is deleted! because of the response_len=11 or len(history)=0
# data 6396 is deleted! because of the response_len=22 or len(history)=0
# data 6434 is deleted! because of the response_len=22 or len(history)=0
# data 6438 is deleted! because of the response_len=31 or len(history)=0
# data 6474 is deleted! because of the response_len=39 or len(history)=0
# data 6485 is deleted! because of the response_len=22 or len(history)=0
# data 6512 is deleted! because of the response_len=40 or len(history)=0
# data 6513 is deleted! because of the response_len=23 or len(history)=0
# data 6523 is deleted! because of the response_len=18 or len(history)=0
# data 6525 is deleted! because of the response_len=14 or len(history)=0
# data 6548 is deleted! because of the response_len=13 or len(history)=0
# data 6552 is deleted! because of the response_len=21 or len(history)=0
# data 6558 is deleted! because of the response_len=18 or len(history)=0
# data 6571 is deleted! because of the response_len=23 or len(history)=0
# data 6604 is deleted! because of the response_len=30 or len(history)=0
# data 6659 is deleted! because of the response_len=16 or len(history)=0
# data 6669 is deleted! because of the response_len=19 or len(history)=0
# data 6671 is deleted! because of the response_len=19 or len(history)=0
# data 6682 is deleted! because of the response_len=8 or len(history)=0
# data 6707 is deleted! because of the response_len=16 or len(history)=0
# data 6754 is deleted! because of the response_len=9 or len(history)=0
# data 6764 is deleted! because of the response_len=10 or len(history)=0
# data 6806 is deleted! because of the response_len=16 or len(history)=0
# data 6807 is deleted! because of the response_len=24 or len(history)=0
# data 6818 is deleted! because of the response_len=31 or len(history)=0
# data 6881 is deleted! because of the response_len=12 or len(history)=0
# data 6883 is deleted! because of the response_len=22 or len(history)=0
# data 6907 is deleted! because of the response_len=8 or len(history)=0
# data 6909 is deleted! because of the response_len=22 or len(history)=0
# data 6926 is deleted! because of the response_len=23 or len(history)=0
# data 6930 is deleted! because of the response_len=27 or len(history)=0
# data 6934 is deleted! because of the response_len=28 or len(history)=0
# data 6939 is deleted! because of the response_len=15 or len(history)=0
# data 6947 is deleted! because of the response_len=29 or len(history)=0
# data 6962 is deleted! because of the response_len=21 or len(history)=0
# data 6971 is deleted! because of the response_len=21 or len(history)=0
# data 6974 is deleted! because of the response_len=24 or len(history)=0
# data 7033 is deleted! because of the response_len=10 or len(history)=0
# data 7041 is deleted! because of the response_len=14 or len(history)=0
# data 7070 is deleted! because of the response_len=27 or len(history)=0
# data 7084 is deleted! because of the response_len=25 or len(history)=0
# data 7086 is deleted! because of the response_len=25 or len(history)=0
# data 7092 is deleted! because of the response_len=23 or len(history)=0
# data 7093 is deleted! because of the response_len=13 or len(history)=0
# data 7121 is deleted! because of the response_len=21 or len(history)=0
# data 7140 is deleted! because of the response_len=27 or len(history)=0
# data 7160 is deleted! because of the response_len=17 or len(history)=0
# data 7195 is deleted! because of the response_len=5 or len(history)=0
# data 7200 is deleted! because of the response_len=22 or len(history)=0
# data 7213 is deleted! because of the response_len=19 or len(history)=0
# data 7228 is deleted! because of the response_len=31 or len(history)=0
# data 7251 is deleted! because of the response_len=24 or len(history)=0
# data 7310 is deleted! because of the response_len=13 or len(history)=0
# data 7351 is deleted! because of the response_len=36 or len(history)=0
# data 7355 is deleted! because of the response_len=9 or len(history)=0
# data 7387 is deleted! because of the response_len=15 or len(history)=0
# data 7400 is deleted! because of the response_len=35 or len(history)=0
# data 7419 is deleted! because of the response_len=23 or len(history)=0
# data 7452 is deleted! because of the response_len=26 or len(history)=0
# data 7479 is deleted! because of the response_len=28 or len(history)=0
# data 7487 is deleted! because of the response_len=23 or len(history)=0
# data 7492 is deleted! because of the response_len=30 or len(history)=0
# data 7532 is deleted! because of the response_len=18 or len(history)=0
# data 7551 is deleted! because of the response_len=20 or len(history)=0
# data 7557 is deleted! because of the response_len=26 or len(history)=0
# data 7561 is deleted! because of the response_len=19 or len(history)=0
# data 7603 is deleted! because of the response_len=23 or len(history)=0
# data 7638 is deleted! because of the response_len=31 or len(history)=0
# data 7660 is deleted! because of the response_len=28 or len(history)=0
# data 7690 is deleted! because of the response_len=5 or len(history)=0
# data 7691 is deleted! because of the response_len=19 or len(history)=0
# data 7692 is deleted! because of the response_len=28 or len(history)=0
# data 7701 is deleted! because of the response_len=26 or len(history)=0
# ...
# data 18282 is deleted! because of the response_len=16 or len(history)=0
# data 18284 is deleted! because of the response_len=21 or len(history)=0
# data 18300 is deleted! because of the response_len=19 or len(history)=0
# data 18328 is deleted! because of the response_len=13 or len(history)=0
# data 18349 is deleted! because of the response_len=22 or len(history)=0
# data 18355 is deleted! because of the response_len=32 or len(history)=0
# data 18368 is deleted! because of the response_len=32 or len(history)=0
# data 18383 is deleted! because of the response_len=29 or len(history)=0
# data 18402 is deleted! because of the response_len=31 or len(history)=0
# data 18411 is deleted! because of the response_len=23 or len(history)=0
# data 18414 is deleted! because of the response_len=26 or len(history)=0
# data 18429 is deleted! because of the response_len=23 or len(history)=0
# data 18445 is deleted! because of the response_len=26 or len(history)=0
# data 18463 is deleted! because of the response_len=29 or len(history)=0
# data 18482 is deleted! because of the response_len=35 or len(history)=0
# data 18501 is deleted! because of the response_len=19 or len(history)=0
# data 18518 is deleted! because of the response_len=23 or len(history)=0
# data 18526 is deleted! because of the response_len=7 or len(history)=0
# data 18543 is deleted! because of the response_len=29 or len(history)=0
# data 18554 is deleted! because of the response_len=33 or len(history)=0
# data 18594 is deleted! because of the response_len=17 or len(history)=0
# data 18598 is deleted! because of the response_len=22 or len(history)=0
# data 18605 is deleted! because of the response_len=20 or len(history)=0
# data 18623 is deleted! because of the response_len=20 or len(history)=0
# data 18624 is deleted! because of the response_len=35 or len(history)=0
# data 18627 is deleted! because of the response_len=41 or len(history)=0
# data 18646 is deleted! because of the response_len=39 or len(history)=0
# data 18672 is deleted! because of the response_len=19 or len(history)=0
# data 18689 is deleted! because of the response_len=11 or len(history)=0
# data 18691 is deleted! because of the response_len=22 or len(history)=0
# data 18698 is deleted! because of the response_len=8 or len(history)=0
# data 18702 is deleted! because of the response_len=17 or len(history)=0
# data 18710 is deleted! because of the response_len=34 or len(history)=0
# data 18717 is deleted! because of the response_len=29 or len(history)=0
# data 18721 is deleted! because of the response_len=24 or len(history)=0
# data 18759 is deleted! because of the response_len=22 or len(history)=0
# data 18776 is deleted! because of the response_len=25 or len(history)=0
# data 18798 is deleted! because of the response_len=28 or len(history)=0
# data 18806 is deleted! because of the response_len=30 or len(history)=0
# data 18817 is deleted! because of the response_len=13 or len(history)=0
# data 18825 is deleted! because of the response_len=17 or len(history)=0
# data 18829 is deleted! because of the response_len=34 or len(history)=0
# data 18830 is deleted! because of the response_len=24 or len(history)=0
# data 18855 is deleted! because of the response_len=37 or len(history)=0
# data 18877 is deleted! because of the response_len=11 or len(history)=0
# data 18887 is deleted! because of the response_len=19 or len(history)=0
# data 18889 is deleted! because of the response_len=20 or len(history)=0
# data 18915 is deleted! because of the response_len=13 or len(history)=0
# data 18920 is deleted! because of the response_len=30 or len(history)=0
# data 18959 is deleted! because of the response_len=26 or len(history)=0
# data 18967 is deleted! because of the response_len=33 or len(history)=0
# data 18975 is deleted! because of the response_len=25 or len(history)=0
# data 19013 is deleted! because of the response_len=24 or len(history)=0
# data 19027 is deleted! because of the response_len=23 or len(history)=0
# data 19032 is deleted! because of the response_len=18 or len(history)=0
# data 19051 is deleted! because of the response_len=19 or len(history)=0
# data 19075 is deleted! because of the response_len=33 or len(history)=0
# data 19077 is deleted! because of the response_len=20 or len(history)=0
# data 19086 is deleted! because of the response_len=30 or len(history)=0
# data 19104 is deleted! because of the response_len=21 or len(history)=0
# data 19180 is deleted! because of the response_len=25 or len(history)=0
# data 19181 is deleted! because of the response_len=19 or len(history)=0
# data 19183 is deleted! because of the response_len=21 or len(history)=0
# data 19196 is deleted! because of the response_len=18 or len(history)=0
# data 19197 is deleted! because of the response_len=18 or len(history)=0
# data 19200 is deleted! because of the response_len=22 or len(history)=0
# data 19212 is deleted! because of the response_len=22 or len(history)=0
# data 19219 is deleted! because of the response_len=17 or len(history)=0
# data 19223 is deleted! because of the response_len=24 or len(history)=0
# data 19224 is deleted! because of the response_len=17 or len(history)=0
# data 19228 is deleted! because of the response_len=16 or len(history)=0
# data 19236 is deleted! because of the response_len=32 or len(history)=0
# data 19256 is deleted! because of the response_len=15 or len(history)=0
# data 19261 is deleted! because of the response_len=26 or len(history)=0
# data 19262 is deleted! because of the response_len=22 or len(history)=0
# data 19266 is deleted! because of the response_len=19 or len(history)=0
# data 19273 is deleted! because of the response_len=14 or len(history)=0
# data 19275 is deleted! because of the response_len=13 or len(history)=0
# data 19276 is deleted! because of the response_len=29 or len(history)=0
# data 19277 is deleted! because of the response_len=29 or len(history)=0
# data 19279 is deleted! because of the response_len=23 or len(history)=0
# data 19281 is deleted! because of the response_len=11 or len(history)=0
# data 19286 is deleted! because of the response_len=43 or len(history)=0
# data 19291 is deleted! because of the response_len=11 or len(history)=0
# data 19300 is deleted! because of the response_len=20 or len(history)=0
# data 19303 is deleted! because of the response_len=5 or len(history)=0
# data 19310 is deleted! because of the response_len=22 or len(history)=0
# data 19337 is deleted! because of the response_len=31 or len(history)=0
# data 19352 is deleted! because of the response_len=13 or len(history)=0
# data 19362 is deleted! because of the response_len=26 or len(history)=0
# data 19366 is deleted! because of the response_len=25 or len(history)=0
# data 19373 is deleted! because of the response_len=19 or len(history)=0
# data 19398 is deleted! because of the response_len=10 or len(history)=0
# data 19441 is deleted! because of the response_len=26 or len(history)=0
# data 19455 is deleted! because of the response_len=15 or len(history)=0
# data 19503 is deleted! because of the response_len=16 or len(history)=0
# data 19511 is deleted! because of the response_len=17 or len(history)=0
# data 19541 is deleted! because of the response_len=31 or len(history)=0
# 19545 -> 18150 = 1395 examples ~7.1% reduction
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type                  | Params
# ----------------------------------------------------
# 0 | bert      | BertForMaskedLM       | 109 M
# 1 | scheduler | DiscreteMaskScheduler | 0
# ----------------------------------------------------
# 109 M     Trainable params
# 0         Non-trainable params
# 109 M     Total params
# 438.057   Total estimated model params size (MB)
# Sanity Checking: |                                                                                  | 0/? [00:…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#       2 model = DiffusionBert(cfg, dm.tokenizer)  # Assuming DiffusionBert class defined earlier
#       3 trainer = pl.Trainer(
#       4     max_steps=cfg.max_steps,
#       5     gradient_clip_val=cfg.gradient_clip_val,
#    (...)
#      10     val_check_interval=cfg.val_check_interval,
#      11 )
# ---> 13 trainer.fit(model, dm)
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:544, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     542 self.state.status = TrainerStatus.RUNNING
#     543 self.training = True
# --> 544 call._call_and_handle_interrupt(
#     545     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     546 )
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:580, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     573 assert self.state.fn is not None
#     574 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     575     self.state.fn,
#     576     ckpt_path,
#     577     model_provided=True,
#     578     model_connected=self.lightning_module is not None,
#     579 )
# --> 580 self._run(model, ckpt_path=ckpt_path)
#     582 assert self.state.stopped
#     583 self.training = False
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:987, in Trainer._run(self, model, ckpt_path)
#     982 self._signal_connector.register_signal_handlers()
#     984 # ----------------------------
#     985 # RUN THE TRAINER
#     986 # ----------------------------
# --> 987 results = self._run_stage()
#     989 # ----------------------------
#     990 # POST-Training CLEAN UP
#     991 # ----------------------------
#     992 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1031, in Trainer._run_stage(self)
#    1029 if self.training:
#    1030     with isolate_rng():
# -> 1031         self._run_sanity_check()
#    1032     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1033         self.fit_loop.run()
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1060, in Trainer._run_sanity_check(self)
#    1057 call._call_callback_hooks(self, "on_sanity_check_start")
#    1059 # run eval step
# -> 1060 val_loop.run()
#    1062 call._call_callback_hooks(self, "on_sanity_check_end")
#    1064 # reset logger connector
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/loops/utilities.py:182, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     180     context_manager = torch.no_grad
#     181 with context_manager():
# --> 182     return loop_run(self, *args, **kwargs)
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/loops/evaluation_loop.py:128, in _EvaluationLoop.run(self)
#     126 else:
#     127     dataloader_iter = None
# --> 128     batch, batch_idx, dataloader_idx = next(data_fetcher)
#     129 if previous_dataloader_idx != dataloader_idx:
#     130     # the dataloader has changed, notify the logger connector
#     131     self._store_dataloader_outputs()
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/loops/fetchers.py:133, in _PrefetchDataFetcher.__next__(self)
#     130         self.done = not self.batches
#     131 elif not self.done:
#     132     # this will run only when no pre-fetching was done.
# --> 133     batch = super().__next__()
#     134 else:
#     135     # the iterator is empty
#     136     raise StopIteration
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/loops/fetchers.py:60, in _DataFetcher.__next__(self)
#      58 self._start_profiler()
#      59 try:
# ---> 60     batch = next(self.iterator)
#      61 except StopIteration:
#      62     self.done = True
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/utilities/combined_loader.py:341, in CombinedLoader.__next__(self)
#     339 def __next__(self) -> _ITERATOR_RETURN:
#     340     assert self._iterator is not None
# --> 341     out = next(self._iterator)
#     342     if isinstance(self._iterator, _Sequential):
#     343         return out
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/pytorch_lightning/utilities/combined_loader.py:142, in _Sequential.__next__(self)
#     139             raise StopIteration
#     141 try:
# --> 142     out = next(self.iterators[0])
#     143 except StopIteration:
#     144     # try the next iterator
#     145     self._use_next_iterator()
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1346, in _MultiProcessingDataLoaderIter._next_data(self)
#    1344 else:
#    1345     del self._task_info[idx]
# -> 1346     return self._process_data(data)
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1372, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1370 self._try_put_index()
#    1371 if isinstance(data, ExceptionWrapper):
# -> 1372     data.reraise()
#    1373 return data
#
# File ~/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/_utils.py:722, in ExceptionWrapper.reraise(self)
#     718 except TypeError:
#     719     # If the exception takes multiple arguments, don't try to
#     720     # instantiate since we don't know how to
#     721     raise RuntimeError(msg) from None
# --> 722 raise exception
#
# ValueError: Caught ValueError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/xueqiang/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/xueqiang/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/xueqiang/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/xueqiang/DialFill-DM/dataset_process/base_conv.py", line 671, in __getitem__
#     item_dict = process_method(
#   File "/home/xueqiang/DialFill-DM/dataset_process/base_conv.py", line 711, in _build_from_segments
#     text_input = self.tokenizer.apply_chat_template(
#   File "/home/xueqiang/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/transformers/tokenization_utils_base.py", line 1786, in apply_chat_template
#     chat_template = self.get_chat_template(chat_template, tools)
#   File "/home/xueqiang/anaconda3/envs/DialFill_DM/lib/python3.9/site-packages/transformers/tokenization_utils_base.py", line 2025, in get_chat_template
#     raise ValueError(
# ValueError: Cannot use apply_chat_template() because tokenizer.chat_template is not set and no template argument was passed! For information about writing templates and setting the tokenizer.chat_template attribute, please see the documentation at https://huggingface.co/docs/transformers/main/en/chat_templating

# %% [markdown]
# ## 7  Sampling demo

# %%
prompts = [
    "In recent years, diffusion models for language have",
    "The quick brown fox"
]
samples = model.sample(
    prompts,
    num_steps=cfg.T,
    start_mask_ratio=0.5,   # 更少初始掩码
    )                       # 在模块里把 topk=10, temperature=0.7

for p, s in zip(prompts, samples):
    print('\nPrompt:', p)
    print('Output:', s)
